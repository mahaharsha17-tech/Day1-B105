# %%
first name = ("chandra")
print(firstname
# Out:
#   Cell In[6], line 1
#     first name = ("chandra")
#           ^
# SyntaxError: invalid syntax

# %%
firstname = ("chandra")
print(firstname)
# Out:
# chandra

# %%
1firstname = ("chandra")
print(1firstname)
# Out:
#   Cell In[10], line 1
#     1firstname = ("chandra")
#     ^
# SyntaxError: invalid decimal literal

# %%
firstname = ("chandra")
print(firstname)
# Out:
# chandra

# %%
firstname@ = ("chandra")
print(firstname@)
# Out:
#   Cell In[12], line 1
#     firstname@ = ("chandra")
#                ^
# SyntaxError: invalid syntax

# %%
type(firstname)
# Out:
# str

# %%
print(firstname.title)
# Out:
# <built-in method title of str object at 0x00000194B7DBDE60>

# %%
firstname = ("chandra")
print(firstname.title)
# Out:
# <built-in method title of str object at 0x00000194B7DBDE60>

# %%
firstname = ("chandra")
print(firstname.title())
# Out:
# Chandra

# %%
firstname = ("chandra")
print(firstname.upper())
# Out:
# CHANDRA

# %%
firstname = ("chandra")
print(firstname.lower)

# %%
students = ['chandru','Maha','harsha','Iniya']
print(students)
# Out:
# ['chandru', 'Maha', 'harsha', 'Iniya']

# %%
type(students)
# Out:
# list

# %%
print(students[2])
# Out:
# harsha

# %%
# i want to add one more name

# %%
students.append('Tamil')
print(students)
# Out:
# ['chandru', 'Maha', 'harsha', 'Iniya', 'Tamil']

# %%
# i want add yalini 2nd index

# %%
students.insert(2,'Yalini')
print(students)
# Out:
# ['chandru', 'Maha', 'Yalini', 'harsha', 'Iniya', 'Tamil']

# %%
#how to modify elements

# %%
students[1] = 'Shyam'
print(students)
# Out:
# ['chandru', 'Shyam', 'Yalini', 'harsha', 'Iniya', 'Tamil']

# %%
# How to delete elements

# %%
del students[2]
print(students)
# Out:
# ['chandru', 'Shyam', 'harsha', 'Iniya', 'Tamil']

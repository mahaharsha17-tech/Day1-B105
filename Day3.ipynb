# %%
firstname = "chandra"
lastname = "kumar"
fullname = f "{firstname}{lastname}
print(fullname)
# Out:
#   Cell In[1], line 3
#     fullname = f "{firstname}{lastname}
#                  ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
firstname = "chandra"
lastname = "kumar"
fullname = f"{firstname}{lastname}"
print(fullname)
# Out:
# chandrakumar

# %%
print(fullname.title())
# Out:
# Chandrakumar

# %%
message = f"Good work!{fullname.title()}
# Out:
#   Cell In[5], line 1
#     message = f"Good work!{fullname.title()}
#               ^
# SyntaxError: unterminated f-string literal (detected at line 1)

# %%
message = f"Good work!{fullname.title()}"
print(message)
# Out:
# Good work!Chandrakumar

# %%
print("Fav program:Pythonjavacc++")
# Out:
# Fav program:Pythonjavacc++

# %%
print("Fav program:\nPython\njava\nc\nc++")
# Out:
# Fav program:
# Python
# java
# c
# c++

# %%
print("Fav program:\n\tPython\n\tjava\n\tc\n\tc++")
# Out:
# Fav program:
# 	Python
# 	java
# 	c
# 	c++

# %%
name = " python"
print(name)
# Out:
#  python

# %%
name1 = "python   "
print(name1)
# Out:
# python

# %%
name2 = "Python"
print(name2)
# Out:
# Python

# %%
name.lstrip()
print(name)
# Out:
#  python

# %%
name1.rstrip()
print(name1)
# Out:
# python
